# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
from nltk.corpus import stopwords

# %%
train_data = open('./Data/train.txt').readlines()
val_data = open('./Data/val.txt').readlines()
test_data = open('./Data/test.txt').readlines()

# %%
len(train_data), len(val_data), len(test_data)
# Out:
# (16000, 2000, 2000)

# %%
full_data = train_data + test_data + val_data
len(full_data)
# Out:
# 20000

# %%
x=[]
y=[]
for line in full_data:
    t=line.split(';')
    x.append(t[0])
    y.append(t[1].replace('\n',''))

# %% [markdown]
# checking labels in y list

# %%
labels = list(set(y))
labels
# Out:
# ['love', 'joy', 'sadness', 'fear', 'surprise', 'anger']

# %%
df = pd.DataFrame({'messages':x,'labels':y})
df.head()
# Out:
#                                             messages   labels
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
df['labels'].value_counts()
# Out:
# labels
# joy         6761
# sadness     5797
# anger       2709
# fear        2373
# love        1641
# surprise     719
# Name: count, dtype: int64

# %%
plt.pie(df['labels'].value_counts(),labels=list(df['labels'].value_counts().keys()))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# wordcloud

# %%
message = x[1]
message = message.lower()
message = 'i am a data sciencist and have package of 48lakh/annum as a starting salary in dubai'

ls_of_words = nltk.word_tokenize(message)

# ls_of_words = nltk.word_tokenize(message) # message.split()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[13], line 5
#       2 message = message.lower()
#       3 message = 'i am a data sciencist and have package of 48lakh/annum as a starting salary in dubai'
# ----> 5 ls_of_words = nltk.word_tokenize(message)
#       7 # ls_of_words = nltk.word_tokenize(message) # message.split()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\nltk\tokenize\__init__.py:129, in word_tokenize(text, language, preserve_line)
#     114 def word_tokenize(text, language="english", preserve_line=False):
#     115     """
#     116     Return a tokenized copy of *text*,
#     117     using NLTK's recommended word tokenizer
#    (...)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
# ...

# %%
def text_cleaning():
    clean_data = []
    for message in messages:
        message = message.lower()

        ls_of_words = nltk.word_tokenize(message) # message.split()
        
    return clean_data

clean_data = text_cleaning()

# %%
full_data
# Out:
# ['i didnt feel humiliated;sadness\n',
#  'i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake;sadness\n',
#  'im grabbing a minute to post i feel greedy wrong;anger\n',
#  'i am ever feeling nostalgic about the fireplace i will know that it is still on the property;love\n',
#  'i am feeling grouchy;anger\n',
#  'ive been feeling a little burdened lately wasnt sure why that was;sadness\n',
#  'ive been taking or milligrams or times recommended amount and ive fallen asleep a lot faster but i also feel like so funny;surprise\n',
#  'i feel as confused about life as a teenager or as jaded as a year old man;fear\n',
#  'i have been with petronas for years i feel that petronas has performed well and made a huge profit;joy\n',
#  'i feel romantic too;love\n',
#  'i feel like i have to make the suffering i m seeing mean something;sadness\n',
# ...

# %%
len(full_data)
# Out:
# 20000
